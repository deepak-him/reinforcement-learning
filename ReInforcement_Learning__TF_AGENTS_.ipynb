# %%
import tensorflow as tf
from tf_agents.environments import suite_gym
from tf_agents.environments import tf_py_environment
from tf_agents.networks import q_network
from tf_agents.agents.dqn import dqn_agent
from tf_agents.replay_buffers import tf_uniform_replay_buffer
from tf_agents.trajectories import trajectory
from tf_agents.utils import common
from tf_agents.policies import random_tf_policy
from tf_agents.metrics import tf_metric
from tf_agents.drivers import dynamic_step_driver

import numpy as np

# %%
## Create the cartpole environment

env_name = 'CartPole-v1'
train_py_env = suite_gym.load(env_name)
eval_py_env = suite_gym.load(env_name)

# %%
## Convert to tf environment

train_env = tf_py_environment.TFPyEnvironment(train_py_env)
eval_env = tf_py_environment.TFPyEnvironment(eval_py_env)

# %%
## Create an agent

q_net = q_network.QNetwork(train_env.observation_spec(),
                           train_env.action_spec(),
                           fc_layer_params=(100,))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
train_step_counter = tf.Variable(0)
agent = dqn_agent.DdqnAgent(train_env.time_step_spec(),
                            train_env.action_spec(),
                            q_network=q_net,
                            optimizer=optimizer,
                            td_errors_loss_fn=common.element_wise_squared_loss,
                            train_step_counter=train_step_counter)

# %%
## Creating a replay buffer

replay_buffer = tf_uniform_replay_buffer.TFUniformReplayBuffer(
    data_spec=agent.collect_data_spec,
    batch_size=train_env.batch_size,
    max_length=100000)

# %%
## Create Policy for Data Collection

random_policy = random_tf_policy.RandomTFPolicy(train_env.time_step_spec(), train_env.action_spec())

## Function to collect steps
def collect_step(environment, policy):
    time_step = environment.current_time_step()
    action_step = policy.action(time_step)
    next_time_step = environment.step(action_step.action)
    traj = trajectory.from_transition(time_step, action_step, next_time_step)
    replay_buffer.add_batch(traj)

# %%
## Prefill the replay buffer

for _ in range(1000):
    collect_step(train_env, random_policy)

# %%
## Evaluation

def compute_avg_return(environment, policy, num_episodes=10):
    total_return = 0.0
    for _ in range(num_episodes):
        time_step = environment.reset()
        episode_return = 0.0
        while not time_step.is_last():
            action_step = policy.action(time_step)
            time_step = environment.step(action_step.action)
            episode_return += time_step.reward
        total_return += episode_return
    average_return = total_return/num_episodes
    return average_return.numpy()[0]

# %%
## Data Collection

dataset = replay_buffer.as_dataset(num_parallel_calls=3,
                                   sample_batch_size=16,
                                   num_steps=2).prefetch(3)
# Out:
# WARNING:tensorflow:From /Users/abhilashchauhan/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/autograph/impl/api.py:377: ReplayBuffer.get_next (from tf_agents.replay_buffers.replay_buffer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `as_dataset(..., single_deterministic_pass=False) instead.

# %%
iterator = iter(dataset)

# %%
## Training the agent

for _ in range(20000):
    collect_step(train_env, agent.collect_policy)
    experience, _ = next(iterator)
    train_loss = agent.train(experience).loss

    step = agent.train_step_counter.numpy()
    if step % 100 == 0:
        avg_return = compute_avg_return(eval_env, agent.policy)
        print('Step: {}, Avg Return: {}, Loss: {}'.format(step, avg_return, train_loss))
# Out:
# WARNING:tensorflow:From /Users/abhilashchauhan/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1260: calling foldr_v2 (from tensorflow.python.ops.functional_ops) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.foldr(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.foldr(fn, elems))
# Step: 100, Avg Return: 9.0, Loss: 1.725217342376709
# Step: 200, Avg Return: 9.600000381469727, Loss: 7.7565178871154785
# Step: 300, Avg Return: 9.399999618530273, Loss: 5.708325386047363
# Step: 400, Avg Return: 9.600000381469727, Loss: 31.228527069091797
# Step: 500, Avg Return: 9.800000190734863, Loss: 2.7479429244995117
# Step: 600, Avg Return: 9.600000381469727, Loss: 19.563976287841797
# Step: 700, Avg Return: 15.800000190734863, Loss: 18.677509307861328
# Step: 800, Avg Return: 14.600000381469727, Loss: 16.022676467895508
# Step: 900, Avg Return: 12.699999809265137, Loss: 39.27983856201172
# Step: 1000, Avg Return: 14.899999618530273, Loss: 36.966400146484375
# Step: 1100, Avg Return: 15.399999618530273, Loss: 1.9076933860778809
# Step: 1200, Avg Return: 10.899999618530273, Loss: 2.102703094482422
# Step: 1300, Avg Return: 8.899999618530273, Loss: 1.478670358657837
# Step: 1400, Avg Return: 32.0, Loss: 23.763784408569336
# Step: 1500, Avg Return: 19.100000381469727, Loss: 35.05075454711914
# Step: 1600, Avg Return: 20.0, Loss: 41.42765808105469
# Step: 1700, Avg Return: 16.5, Loss: 11.529848098754883
# Step: 1800, Avg Return: 25.399999618530273, Loss: 2.3005566596984863
# Step: 1900, Avg Return: 22.399999618530273, Loss: 1.5409626960754395
# Step: 2000, Avg Return: 9.399999618530273, Loss: 49.28127670288086
# Step: 2100, Avg Return: 9.399999618530273, Loss: 40.8399772644043
# Step: 2200, Avg Return: 26.899999618530273, Loss: 58.151241302490234
# Step: 2300, Avg Return: 16.299999237060547, Loss: 1.611942172050476
# Step: 2400, Avg Return: 20.100000381469727, Loss: 23.733524322509766
# Step: 2500, Avg Return: 18.899999618530273, Loss: 1.6825037002563477
# Step: 2600, Avg Return: 20.5, Loss: 36.780967712402344
# Step: 2700, Avg Return: 31.100000381469727, Loss: 1.2495986223220825
# Step: 2800, Avg Return: 18.600000381469727, Loss: 49.10748291015625
# Step: 2900, Avg Return: 25.600000381469727, Loss: 41.37811279296875
# Step: 3000, Avg Return: 18.5, Loss: 14.062403678894043
# Step: 3100, Avg Return: 35.0, Loss: 26.345848083496094
# Step: 3200, Avg Return: 16.100000381469727, Loss: 61.53382110595703
# Step: 3300, Avg Return: 15.5, Loss: 2.256345272064209
# Step: 3400, Avg Return: 25.100000381469727, Loss: 23.4500789642334
# Step: 3500, Avg Return: 20.200000762939453, Loss: 40.826316833496094
# Step: 3600, Avg Return: 42.20000076293945, Loss: 49.42677307128906
# Step: 3700, Avg Return: 19.5, Loss: 19.90712547302246
# Step: 3800, Avg Return: 22.299999237060547, Loss: 21.20412254333496
# Step: 3900, Avg Return: 20.200000762939453, Loss: 3.01096248626709
# Step: 4000, Avg Return: 26.899999618530273, Loss: 5.97736930847168
# Step: 4100, Avg Return: 41.599998474121094, Loss: 19.277070999145508
# Step: 4200, Avg Return: 21.299999237060547, Loss: 33.65400314331055
# Step: 4300, Avg Return: 22.600000381469727, Loss: 5.618762016296387
# Step: 4400, Avg Return: 26.600000381469727, Loss: 3.0252223014831543
# Step: 4500, Avg Return: 34.900001525878906, Loss: 26.33434295654297
# Step: 4600, Avg Return: 36.5, Loss: 67.09159088134766
# Step: 4700, Avg Return: 37.400001525878906, Loss: 37.20565414428711
# Step: 4800, Avg Return: 65.5, Loss: 3.879750967025757
# Step: 4900, Avg Return: 44.5, Loss: 6.70552921295166
# Step: 5000, Avg Return: 36.400001525878906, Loss: 95.64978790283203
# Step: 5100, Avg Return: 47.20000076293945, Loss: 25.88330841064453
# Step: 5200, Avg Return: 55.099998474121094, Loss: 67.9372329711914
# Step: 5300, Avg Return: 24.799999237060547, Loss: 26.276826858520508
# Step: 5400, Avg Return: 30.0, Loss: 13.288822174072266
# Step: 5500, Avg Return: 40.400001525878906, Loss: 121.48246765136719
# Step: 5600, Avg Return: 28.399999618530273, Loss: 5.9445881843566895
# Step: 5700, Avg Return: 71.19999694824219, Loss: 4.644061088562012
# Step: 5800, Avg Return: 82.69999694824219, Loss: 55.02670669555664
# Step: 5900, Avg Return: 91.0, Loss: 271.05633544921875
# Step: 6000, Avg Return: 54.099998474121094, Loss: 5.796446800231934
# Step: 6100, Avg Return: 40.0, Loss: 39.42844009399414
# Step: 6200, Avg Return: 117.80000305175781, Loss: 7.246674537658691
# Step: 6300, Avg Return: 85.5999984741211, Loss: 111.90718078613281
# Step: 6400, Avg Return: 47.0, Loss: 138.57308959960938
# Step: 6500, Avg Return: 59.5, Loss: 129.6845703125
# Step: 6600, Avg Return: 211.10000610351562, Loss: 4.358696460723877
# Step: 6700, Avg Return: 39.400001525878906, Loss: 4.145622730255127
# Step: 6800, Avg Return: 54.099998474121094, Loss: 78.87123107910156
# Step: 6900, Avg Return: 60.099998474121094, Loss: 15.807645797729492
# Step: 7000, Avg Return: 21.799999237060547, Loss: 163.3538360595703
# Step: 7100, Avg Return: 59.29999923706055, Loss: 6.453837871551514
# Step: 7200, Avg Return: 51.20000076293945, Loss: 5.232333183288574
# Step: 7300, Avg Return: 89.0, Loss: 86.91292572021484
# Step: 7400, Avg Return: 162.1999969482422, Loss: 5.762360095977783
# Step: 7500, Avg Return: 80.80000305175781, Loss: 4.5721001625061035
# Step: 7600, Avg Return: 122.69999694824219, Loss: 9.591117858886719
# Step: 7700, Avg Return: 91.69999694824219, Loss: 114.95894622802734
# Step: 7800, Avg Return: 154.10000610351562, Loss: 195.6294403076172
# Step: 7900, Avg Return: 47.20000076293945, Loss: 6.814505100250244
# Step: 8000, Avg Return: 63.900001525878906, Loss: 5.178561210632324
# Step: 8100, Avg Return: 59.0, Loss: 101.23727416992188
# Step: 8200, Avg Return: 31.0, Loss: 108.8031234741211
# Step: 8300, Avg Return: 60.900001525878906, Loss: 5.537013530731201
# Step: 8400, Avg Return: 59.70000076293945, Loss: 5.076556205749512
# Step: 8500, Avg Return: 50.20000076293945, Loss: 81.3458251953125
# Step: 8600, Avg Return: 143.10000610351562, Loss: 72.159912109375
# Step: 8700, Avg Return: 120.80000305175781, Loss: 521.1783447265625
# Step: 8800, Avg Return: 228.3000030517578, Loss: 209.51901245117188
# Step: 8900, Avg Return: 143.3000030517578, Loss: 9.3324556350708
# Step: 9000, Avg Return: 55.599998474121094, Loss: 5.078118324279785
# Step: 9100, Avg Return: 98.80000305175781, Loss: 10.888813018798828
# Step: 9200, Avg Return: 88.5999984741211, Loss: 7.228874683380127
# Step: 9300, Avg Return: 77.80000305175781, Loss: 17.584224700927734
# Step: 9400, Avg Return: 128.0, Loss: 136.5192413330078
# Step: 9500, Avg Return: 76.5999984741211, Loss: 185.46990966796875
# Step: 9600, Avg Return: 111.0999984741211, Loss: 98.40743255615234
# Step: 9700, Avg Return: 148.3000030517578, Loss: 199.08053588867188
# Step: 9800, Avg Return: 66.0999984741211, Loss: 6.474079132080078
# Step: 9900, Avg Return: 139.8000030517578, Loss: 13.31558895111084
# Step: 10000, Avg Return: 53.20000076293945, Loss: 6.300403594970703
# Step: 10100, Avg Return: 153.6999969482422, Loss: 12.872051239013672
# Step: 10200, Avg Return: 132.3000030517578, Loss: 5.083318710327148
# Step: 10300, Avg Return: 49.5, Loss: 21.585651397705078
# Step: 10400, Avg Return: 170.60000610351562, Loss: 6.182671070098877
# Step: 10500, Avg Return: 158.89999389648438, Loss: 5.061108112335205
# Step: 10600, Avg Return: 143.1999969482422, Loss: 7.231995582580566
# Step: 10700, Avg Return: 74.9000015258789, Loss: 348.5213623046875
# Step: 10800, Avg Return: 151.0, Loss: 6.892826080322266
# Step: 10900, Avg Return: 118.0999984741211, Loss: 245.77523803710938
# Step: 11000, Avg Return: 85.4000015258789, Loss: 6.34773063659668
# Step: 11100, Avg Return: 179.89999389648438, Loss: 9.927495956420898
# Step: 11200, Avg Return: 67.30000305175781, Loss: 15.35458755493164
# Step: 11300, Avg Return: 152.3000030517578, Loss: 10.339847564697266
# Step: 11400, Avg Return: 98.30000305175781, Loss: 9.834723472595215
# Step: 11500, Avg Return: 224.3000030517578, Loss: 5.123469352722168
# Step: 11600, Avg Return: 147.39999389648438, Loss: 8.299418449401855
# Step: 11700, Avg Return: 172.39999389648438, Loss: 233.31329345703125
# Step: 11800, Avg Return: 190.3000030517578, Loss: 6.134790897369385
# Step: 11900, Avg Return: 200.1999969482422, Loss: 11.264923095703125
# Step: 12000, Avg Return: 203.6999969482422, Loss: 9.151493072509766
# Step: 12100, Avg Return: 167.6999969482422, Loss: 9.278715133666992
# Step: 12200, Avg Return: 151.0, Loss: 5.827398300170898
# Step: 12300, Avg Return: 133.39999389648438, Loss: 7.1077880859375
# Step: 12400, Avg Return: 101.19999694824219, Loss: 9.064617156982422
# Step: 12500, Avg Return: 176.3000030517578, Loss: 8.798072814941406
# Step: 12600, Avg Return: 89.5, Loss: 473.1714782714844
# Step: 12700, Avg Return: 128.5, Loss: 7.5489020347595215
# Step: 12800, Avg Return: 134.60000610351562, Loss: 201.88917541503906
# Step: 12900, Avg Return: 166.8000030517578, Loss: 5.541419506072998
# Step: 13000, Avg Return: 178.5, Loss: 5.755671501159668
# Step: 13100, Avg Return: 149.5, Loss: 8.98825454711914
# Step: 13200, Avg Return: 170.3000030517578, Loss: 12.046817779541016
# Step: 13300, Avg Return: 230.3000030517578, Loss: 7.5077409744262695
# Step: 13400, Avg Return: 125.9000015258789, Loss: 382.19317626953125
# Step: 13500, Avg Return: 238.5, Loss: 10.509087562561035
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 4
#       1 ## Training the agent
#       3 for _ in range(20000):
# ----> 4     collect_step(train_env, agent.collect_policy)
#       5     experience, _ = next(iterator)
#       6     train_loss = agent.train(experience).loss
#
# Cell In[13], line 8, in collect_step(environment, policy)
#       6 def collect_step(environment, policy):
#       7     time_step = environment.current_time_step()
# ----> 8     action_step = policy.action(time_step)
#       9     next_time_step = environment.step(action_step.action)
#      10     traj = trajectory.from_transition(time_step, action_step, next_time_step)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/policies/tf_policy.py:333, in TFPolicy.action(self, time_step, policy_state, seed)
#     331 if self._automatic_state_reset:
#     332   policy_state = self._maybe_reset_state(time_step, policy_state)
# --> 333 step = action_fn(time_step=time_step, policy_state=policy_state, seed=seed)
#     335 def clip_action(action, action_spec):
#     336   if isinstance(action_spec, tensor_spec.BoundedTensorSpec):
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/utils/common.py:193, in function_in_tf1.<locals>.maybe_wrap.<locals>.with_check_resource_vars(*fn_args, **fn_kwargs)
#     189 check_tf1_allowed()
#     190 if has_eager_been_enabled():
#     191   # We're either in eager mode or in tf.function mode (no in-between); so
#     192   # autodep-like behavior is already expected of fn.
# --> 193   return fn(*fn_args, **fn_kwargs)
#     194 if not resource_variables_enabled():
#     195   raise RuntimeError(MISSING_RESOURCE_VARIABLES_ERROR)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/policies/epsilon_greedy_policy.py:122, in EpsilonGreedyPolicy._action(self, time_step, policy_state, seed)
#     120 def _action(self, time_step, policy_state, seed):  # pytype: disable=signature-mismatch  # overriding-parameter-count-checks
#     121   seed_stream = tfp.util.SeedStream(seed=seed, salt='epsilon_greedy')
# --> 122   greedy_action = self._greedy_policy.action(time_step, policy_state)
#     123   random_action = self._random_policy.action(time_step, (), seed_stream())
#     125   outer_shape = nest_utils.get_outer_shape(time_step, self._time_step_spec)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/policies/tf_policy.py:333, in TFPolicy.action(self, time_step, policy_state, seed)
#     331 if self._automatic_state_reset:
#     332   policy_state = self._maybe_reset_state(time_step, policy_state)
# --> 333 step = action_fn(time_step=time_step, policy_state=policy_state, seed=seed)
#     335 def clip_action(action, action_spec):
#     336   if isinstance(action_spec, tensor_spec.BoundedTensorSpec):
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/utils/common.py:193, in function_in_tf1.<locals>.maybe_wrap.<locals>.with_check_resource_vars(*fn_args, **fn_kwargs)
#     189 check_tf1_allowed()
#     190 if has_eager_been_enabled():
#     191   # We're either in eager mode or in tf.function mode (no in-between); so
#     192   # autodep-like behavior is already expected of fn.
# --> 193   return fn(*fn_args, **fn_kwargs)
#     194 if not resource_variables_enabled():
#     195   raise RuntimeError(MISSING_RESOURCE_VARIABLES_ERROR)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/policies/tf_policy.py:589, in TFPolicy._action(self, time_step, policy_state, seed)
#     574 """Implementation of `action`.
#     575
#     576 Args:
#    (...)
#     586     `info`: Optional side information such as action log probabilities.
#     587 """
#     588 seed_stream = tfp.util.SeedStream(seed=seed, salt='tf_agents_tf_policy')
# --> 589 distribution_step = self._distribution(time_step, policy_state)  # pytype: disable=wrong-arg-types
#     590 actions = tf.nest.map_structure(
#     591     lambda d: reparameterized_sampling.sample(d, seed=seed_stream()),
#     592     distribution_step.action,
#     593 )
#     594 info = distribution_step.info
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/policies/greedy_policy.py:82, in GreedyPolicy._distribution(self, time_step, policy_state)
#      75     raise ValueError(
#      76         "Your network's distribution does not implement mode "
#      77         'making it incompatible with a greedy policy.'
#      78     ) from NotImplementedError
#      80   return tfp.distributions.Deterministic(loc=greedy_action)
# ---> 82 distribution_step = self._wrapped_policy.distribution(
#      83     time_step, policy_state
#      84 )
#      85 return policy_step.PolicyStep(
#      86     tf.nest.map_structure(dist_fn, distribution_step.action),
#      87     distribution_step.state,
#      88     distribution_step.info,
#      89 )
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/policies/tf_policy.py:422, in TFPolicy.distribution(self, time_step, policy_state)
#     420 if self._automatic_state_reset:
#     421   policy_state = self._maybe_reset_state(time_step, policy_state)
# --> 422 step = self._distribution(time_step=time_step, policy_state=policy_state)
#     423 if self.emit_log_probability:
#     424   # This here is set only for compatibility with info_spec in constructor.
#     425   info = policy_step.set_log_probability(
#     426       step.info,
#     427       tf.nest.map_structure(
#    (...)
#     430       ),
#     431   )
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/policies/q_policy.py:162, in QPolicy._distribution(self, time_step, policy_state)
#     157 if observation_and_action_constraint_splitter is not None:
#     158   network_observation, mask = observation_and_action_constraint_splitter(
#     159       network_observation
#     160   )
# --> 162 q_values, policy_state = self._q_network(
#     163     network_observation,
#     164     network_state=policy_state,
#     165     step_type=time_step.step_type,
#     166 )
#     168 logits = q_values
#     170 if observation_and_action_constraint_splitter is not None:
#     171   # Overwrite the logits for invalid actions to logits.dtype.min.
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/networks/network.py:440, in Network.__call__(self, inputs, *args, **kwargs)
#     432 if (
#     433     not tf.is_tensor(network_state)
#     434     and network_state in (None, ())
#     435     and "network_state" not in call_argspec.args
#     436     and not call_argspec.keywords
#     437 ):
#     438   normalized_kwargs.pop("network_state", None)
# --> 440 outputs, new_state = super(Network, self).__call__(**normalized_kwargs)  # pytype: disable=attribute-error  # typed-keras
#     442 nest_utils.assert_matching_dtypes_and_inner_shapes(
#     443     new_state,
#     444     self.state_spec,
#    (...)
#     448     specs_name="`state_spec`",
#     449 )
#     451 return outputs, new_state
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tf_agents/networks/q_network.py:157, in QNetwork.call(self, observation, step_type, network_state, training)
#     139 """Runs the given observation through the network.
#     140
#     141 Args:
#    (...)
#     149   A tuple `(logits, network_state)`.
#     150 """
#     151 state, network_state = self._encoder(
#     152     observation,
#     153     step_type=step_type,
#     154     network_state=network_state,
#     155     training=training,
#     156 )
# --> 157 q_value = self._q_value_layer(state, training=training)
#     158 return q_value, network_state
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/layers/core/dense.py:144, in Dense.call(self, inputs, training)
#     143 def call(self, inputs, training=None):
# --> 144     x = ops.matmul(inputs, self.kernel)
#     145     if self.bias is not None:
#     146         x = ops.add(x, self.bias)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/ops/numpy.py:3445, in matmul(x1, x2)
#    3443 if any_symbolic_tensors((x1, x2)):
#    3444     return Matmul().symbolic_call(x1, x2)
# -> 3445 return backend.numpy.matmul(x1, x2)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/backend/tensorflow/numpy.py:377, in matmul(x1, x2)
#     375     output_type = None
#     376 x1 = tf.cast(x1, compute_dtype)
# --> 377 x2 = tf.cast(x2, compute_dtype)
#     379 def with_combined_batch_dimensions(a, b, output_shape, fn_3d):
#     380     a_sparse = isinstance(a, tf.SparseTensor)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/ops/math_ops.py:1012, in cast(x, dtype, name)
#    1006   x = indexed_slices.IndexedSlices(values_cast, x.indices, x.dense_shape)
#    1007 else:
#    1008   # TODO(josh11b): If x is not already a Tensor, we could return
#    1009   # ops.convert_to_tensor(x, dtype=dtype, ...)  here, but that
#    1010   # allows some conversions that cast() can't do, e.g. casting numbers to
#    1011   # strings.
# -> 1012   x = ops.convert_to_tensor(x, name="x")
#    1013   if x.dtype.is_complex and base_type.is_floating:
#    1014     logging.warn(
#    1015         f"You are casting an input of type {x.dtype.name} to an "
#    1016         f"incompatible dtype {base_type.name}.  This will "
#    1017         "discard the imaginary part and may not be what you "
#    1018         "intended."
#    1019     )
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:713, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     711 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     712 preferred_dtype = preferred_dtype or dtype_hint
# --> 713 return tensor_conversion_registry.convert(
#     714     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     715 )
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/keras/src/backend/tensorflow/core.py:77, in Variable.__tf_tensor__(self, dtype, name)
#      76 def __tf_tensor__(self, dtype=None, name=None):
# ---> 77     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/framework/tensor_conversion.py:161, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#      96 @tf_export.tf_export("convert_to_tensor", v1=[])
#      97 @dispatch.add_dispatch_support
#      98 def convert_to_tensor_v2_with_dispatch(
#      99     value, dtype=None, dtype_hint=None, name=None
#     100 ) -> tensor_lib.Tensor:
#     101   """Converts the given `value` to a `Tensor`.
#     102
#     103   This function converts Python objects of various types to `Tensor`
#    (...)
#     159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/framework/tensor_conversion.py:171, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169 """Converts the given `value` to a `Tensor`."""
#     170 # preferred_dtype = preferred_dtype or dtype_hint
# --> 171 return tensor_conversion_registry.convert(
#     172     value, dtype, name, preferred_dtype=dtype_hint
#     173 )
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:2375, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2374 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2375   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:1621, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1619   return self.read_value().op.inputs[0]
#    1620 else:
# -> 1621   return self.value()
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:656, in BaseResourceVariable.value(self)
#     654   return self._cached_value
#     655 with ops.colocate_with(None, ignore_existing=True):
# --> 656   return self._read_variable_op()
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:841, in BaseResourceVariable._read_variable_op(self, no_copy)
#     839       result = read_and_set_handle(no_copy)
#     840 else:
# --> 841   result = read_and_set_handle(no_copy)
#     843 if not context.executing_eagerly():
#     844   # Note that if a control flow context is active the input of the read op
#     845   # might not actually be the handle. This line bypasses it.
#     846   record.record_operation(
#     847       "ReadVariableOp", [result], [self.handle],
#     848       backward_function=lambda x: [x],
#     849       forward_function=lambda x: [x])
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:831, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     829 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     830   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 831 result = gen_resource_variable_ops.read_variable_op(
#     832     self.handle, self._dtype)
#     833 _maybe_set_handle_data(self._dtype, self.handle, result)
#     834 return result
#
# File ~/anaconda3/envs/reinforcement/lib/python3.11/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py:534, in read_variable_op(resource, dtype, name)
#     532 if tld.is_eager:
#     533   try:
# --> 534     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     535       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     536     return _result
#     537   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
